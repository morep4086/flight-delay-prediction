# %% [markdown]
# # Data Exploration - Flight Delay Prediction
# **Student:** Pooja More
# **Project ID:** AIML024

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('../data/raw/flights.csv')
print(f"Dataset shape: {df.shape}")
df.head()

# %%
# Basic statistics
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %%
# Delay distribution
plt.figure(figsize=(10, 6))
df['IS_DELAY'].value_counts().plot(kind='bar')
plt.title('Flight Delay Distribution')
plt.show()

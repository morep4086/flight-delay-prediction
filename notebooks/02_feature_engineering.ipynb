# %% [markdown]
# # Feature Engineering - Flight Delay Prediction
# **Student:** Pooja More
# **Project ID:** AIML024

# %%
import pandas as pd
import numpy as np

# Load processed data
df = pd.read_csv('../data/processed/processed_flights.csv')
print(f"Processed dataset shape: {df.shape}")
df.head()

# %%
# Feature correlation analysis
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()

# %%
# Feature importance analysis
feature_cols = [col for col in df.columns if col not in ['DEP_DELAY', 'IS_DELAY']]
print(f"Number of features: {len(feature_cols)}")
print("Features:", feature_cols[:10])  # Show first 10 features
